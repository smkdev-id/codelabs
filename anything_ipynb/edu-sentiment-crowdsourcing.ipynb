# %% [markdown]
# ### **8. Crowdsourcing and Crowdfunding for VocaRiset**
# **Functionality:**
# A platform to crowdsource research ideas and crowdfunding support for projects.
#
# **Features:**
# - AI to rank and prioritize ideas based on feasibility, impact, and interest.
# - Predictive analytics for funding trends and resource allocation.
# - Transparency tools powered by AI for tracking project milestones and deliverables.

# %%
# !pip list
# Out:
# Package                       Version        Editable project location
# ----------------------------- -------------- --------------------------------
# absl-py                       2.1.0
# aiohttp                       3.9.5
# aiosignal                     1.3.1
# alabaster                     0.7.16
# altair                        5.3.0
# annotated-types               0.7.0
# anyio                         4.4.0
# appdirs                       1.4.4
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# array_record                  0.5.1
# arrow                         1.3.0
# asgiref                       3.8.1
# asttokens                     2.4.1
# astunparse                    1.6.3
# async-lru                     2.0.4
# attrs                         23.2.0
# Babel                         2.15.0
# beautifulsoup4                4.12.3
# bleach                        6.1.0
# blinker                       1.8.2
# branca                        0.8.0
# ...
